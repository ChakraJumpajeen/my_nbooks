# %% [markdown]
# # Chapter 4: The Seaborn essentials for data visualization

# %%
import pandas as pd

# %% [markdown]
# ## Get the data

# %%
mortality_data = pd.read_pickle('mortality_prepped.pkl')
mortality_data.head()
# Out:
#    Year     AgeGroup  DeathRate  MeanCentered
# 0  1900  01-04 Years     1983.8    1790.87584
# 1  1901  01-04 Years     1695.0    1502.07584
# 2  1902  01-04 Years     1655.7    1462.77584
# 3  1903  01-04 Years     1542.1    1349.17584
# 4  1904  01-04 Years     1591.5    1398.57584

# %% [markdown]
# ## The basic Seaborn parameters

# %%
import seaborn as sns

# %%
sns.relplot(data=mortality_data, kind='line',
            x='Year', y='DeathRate', hue='AgeGroup')

# %%
sns.lineplot(data=mortality_data, 
             x='Year', y='DeathRate', hue='AgeGroup')
# Out:
# <Axes: xlabel='Year', ylabel='DeathRate'>

# %%
#3. Change the aspect parameter for the plot in cell 6 to 2. 
# Original Code below
# sns.relplot(data=mortality_data, kind='line', x='Year', y='DeathRate', hue='AgeGroup', palette='bright', height=4, aspect=1.5)

sns.relplot(data=mortality_data, kind='line', 
            x='Year', y='DeathRate', hue='AgeGroup', palette='bright',
            height=4, aspect=2)

# %%
sns.relplot(data=mortality_data, 
            kind='line', x='Year', y='DeathRate', hue='AgeGroup', 
            height=4, aspect=1.25, 
            col='AgeGroup', col_wrap=2, legend=False)

# %% [markdown]
# ## Enhancing plots

# %%
ax = sns.lineplot(data=mortality_data, 
                  x='Year', y='DeathRate', hue='AgeGroup')
ax.set(title='Deaths by Age Group', ylabel='Deaths per 100,000')
# Out:
# [Text(0.5, 1.0, 'Deaths by Age Group'), Text(0, 0.5, 'Deaths per 100,000')]

# %%
g = sns.relplot(data=mortality_data, kind='line',
    x='Year', y='DeathRate', hue='AgeGroup', aspect=1.5)
for ax in g.axes.flat:
    ax.set(title='Deaths by Age Group', ylabel='Deaths per 100,000')

# %%
# 4. Change cell 10 so every fifth year is displayed on the x-axis for the plot and so the labels on the x-axis are displayed at their default rotation.
# Original Code below
# xticks=[x for x in range(1910, 1931, 2)],

g = sns.relplot(data=mortality_data, kind='line',
    x='Year', y='DeathRate', hue='AgeGroup', aspect=1.25)
for ax in g.axes.flat:
    ax.set(title='Deaths by Age Group (1910-1930)', ylabel='Deaths per 100,000', 
        xticks=[x for x in range(1910, 1931, 10)], 
        xlim=(1910,1930), ylim=(0,1750)),
    ax.tick_params('x', labelrotation=30)

# %%
ax = sns.lineplot(data=mortality_data,
     x='Year', y='DeathRate', hue='AgeGroup')
ax.set(title='Deaths by Age Group (1910-1930)', 
      ylabel='Deaths per 100,000', 
      xticks=[x for x in range(1910,1931,2)], 
      xlim=(1910,1930), ylim=(0,1750))
ax.tick_params('x', labelrotation=30)

# %%
sns.set_style('whitegrid')
sns.relplot(data=mortality_data.query('Year >= 1910 and Year <= 1930'),
    kind='line', x='Year', y='DeathRate', hue='AgeGroup', aspect=1.25)

# %%
sns.set_style('darkgrid')
sns.relplot(data=mortality_data.query('Year >= 1910 and Year <= 1930'),
    kind='line', x='Year', y='DeathRate', hue='AgeGroup', aspect=1.25)

# %%
sns.set_style('ticks')

# %%
g = sns.relplot(data=mortality_data.query('Year >= 1910 and Year <= 1930'),
    kind='line', x='Year', y='DeathRate', hue='AgeGroup', legend=False,
    col='AgeGroup', col_wrap=2, height=4)
g.fig.suptitle('Deaths by Age Group (1910-1930)', y=1.025)
g.set(ylabel='Deaths per 100,000', 
      xticks=[x for x in range(1910,1931,3)], 
      ylim=(0,1750))

# %% [markdown]
# ## Relational plots

# %%
sns.relplot(data=mortality_data, kind='line', x='Year', y='DeathRate', 
            hue='AgeGroup')

# %%
# 5. Change cell 17 so the confidence interval for the plot shows the standard deviation.
# Original Code below
# sns.relplot(data=mortality_data, kind='line', x='Year', y='DeathRate')

sns.relplot(data=mortality_data, kind='line', x='Year', y='DeathRate', hue='AgeGroup')

# %%
sns.relplot(data=mortality_data, kind='scatter', x='Year', y='DeathRate', 
            hue='AgeGroup')

# %%
# 6. Change cell 19 so it uses a specific method to create the scatter plot. 
# Original Code below

# g = sns.relplot(data=mortality_data.query('Year >= 1910 and Year <= 1930'), 
#     kind='scatter', x='Year', y='DeathRate', hue='AgeGroup', 
#     size='DeathRate', sizes=(10,100))
# for ax in g.axes.flat:
#     ax.set(xticks=[x for x in range(1910,1931,2)])

sns.relplot(data=mortality_data.query('Year >= 1910 and Year <= 1930'), kind='scatter', x='Year', y='DeathRate', hue='AgeGroup')

# %% [markdown]
# ## Categorical plots

# %%
# 7. Change cell 20 so it uses a specific method to create the bar plot, and change the confidence interval to 75.
# Original Code below
# sns.catplot(data=mortality_data.query('Year in (1950,2000)'), 
#             kind='bar', x='Year', y='DeathRate', ci=50)

sns.catplot(data=mortality_data.query('Year in (1950,2000)'), 
            kind='bar', x='Year', y='DeathRate', ci=75)
# Out:
# /var/folders/dd/gbd6vl0j6m9g65j67lnzff_c0000gn/T/ipykernel_59084/1808077727.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 75)` for the same effect.
#
#   sns.catplot(data=mortality_data.query('Year in (1950,2000)'),

# %%
sns.catplot(data=mortality_data.query('Year in (1950,2000)'), 
            kind='bar', x='DeathRate', y='Year', hue='AgeGroup', orient='h')

# %%
sns.catplot(data=mortality_data.query('Year >= 1915 and Year <= 1920'), 
            kind='box', x='Year', y='DeathRate')

# %%
sns.catplot(data=mortality_data,
            kind='box', x='DeathRate', y='AgeGroup', orient='h')

# %% [markdown]
# ## Distribution plots

# %%
sns.displot(data=mortality_data, kind='hist', x='DeathRate')

# %%
# 8. Change cell 25 so the histogram uses twice as many bins as it currently does. 
# Original Code below
# sns.displot(data=mortality_data, kind='hist', x='DeathRate', bins=8)

sns.displot(data=mortality_data, kind='hist', x='DeathRate', bins=16)

# %%
sns.displot(data=mortality_data, kind='kde', x='DeathRate')

# %%
sns.displot(data=mortality_data, kind='ecdf', x='DeathRate', hue='AgeGroup')

# %%
sns.displot(data=mortality_data, kind='hist', 
            x='DeathRate', kde=True, bins=8)

# %%
sns.displot(data=mortality_data, kind='kde', x='DeathRate', hue='AgeGroup', 
            fill=True, col='AgeGroup', col_wrap=2, height=3, legend=False)

# %% [markdown]
# ## Other techniques for enhancing a plot

# %%
g = sns.relplot(
    data=mortality_data, 
    kind='line', x='Year', y='DeathRate', hue='AgeGroup', aspect=1.25)
for ax in g.axes.flat:
    ax.set_title('Deaths by Age Group (2000-2016)')
    ax.set_xlabel('')
    ax.set_xticks([x for x in range(2000,2017,2)])
    ax.set_xticklabels(['Year ' + str(x) for x in range(0,17,2)])
    ax.tick_params('x', labelrotation=30)
    ax.set_ylabel('Deaths per 100,000')
    ax.set_xlim(2000,2016)
    ax.set_ylim(0,80)

# %%
ax = sns.lineplot(data=mortality_data, 
                  x='Year', y='DeathRate', hue='AgeGroup')
ax.set_title('Deaths by Age Group')
ax.set_ylabel('Deaths per 100,000')
ax.annotate(text='Spanish Flu Pandemic', 
    xy=(1918, 1650), xytext=(1925, 1900), 
    arrowprops=dict(facecolor='red', width=3, headwidth=12, headlength=6))
# Out:
# Text(1925, 1900, 'Spanish Flu Pandemic')

# %%
colors = ['black','red','orange','blue']
sns.set_palette(sns.color_palette(colors))
sns.relplot(data=mortality_data, kind='line',
            x='Year', y='DeathRate', hue='AgeGroup')

# %%
sns.set_palette(sns.color_palette('tab10'))

# %%
g = sns.relplot(
    data=mortality_data.query('Year >= 1910 and Year <= 1930'),
    kind='line', x='Year', y='DeathRate', hue='AgeGroup', legend=False,
    col='AgeGroup', col_wrap=2, height=3, aspect=1.2)
g.fig.suptitle('Deaths by Age Group (1910-1930)', y=1.025)
for ax in g.axes.flat:
    ax.set_ylabel('Deaths per 100,000')
    ax.set_xticks([x for x in range(1910, 1931, 2)])
    ax.tick_params('x', labelrotation=45)

# %%
g = sns.relplot(
    data=mortality_data.query('Year >= 1910 and Year <= 1930'), 
    kind='line', x='Year', y='DeathRate', hue='AgeGroup', legend=False, 
    col='AgeGroup', col_wrap=2, height=3, aspect=1.2)
g.fig.suptitle('Deaths by Age Group (1910-1930)', y=1.025)
ageGroups = mortality_data['AgeGroup'].drop_duplicates().tolist()
for index, ax in enumerate(g.axes.flat):
    ax.set_title(ageGroups[index])
    ax.set_ylabel('Deaths per 100,000')
    ax.set_xticks([x for x in range(1910, 1931, 2)])
    ax.tick_params('x', labelrotation=45)

# %%
# import a Matplotlib module and set the figure size
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(10,7.5)) 

# create the line plot
sns.lineplot(data=mortality_data, x='Year', y='DeathRate', hue='AgeGroup')

# use the ax and fig objects to enhance and save the plot
ax.set(title='Deaths by Age Group (1910-1930)', 
    ylabel='Deaths per 100,000', 
    xticks=[x for x in range(1910, 1931, 2)], 
    xlim=(1910,1930), ylim=(0,1750)),
ax.tick_params('x', labelrotation=45)

# %% [markdown]
# ## Prepare some plots of your own
# As you create the plots in the steps that follow, don’t create new DataFrames, but note that you may need to chain some of the methods.

# %%
# 9. Create a vertical bar plot that shows the deaths rates for the four age groups for the years 1900, 1950, and 2000, and 
#    note that the bars represent the average death rates for the three years.  
#    Now, modify the plot so it shows the death rates for each of the three years, and increase the width of the plot so it’s 1.8 times the height of the plot.

sns.catplot(
    data=mortality_data.query('Year in [1900, 1950, 2000]'),
    kind='bar',
    x='AgeGroup',
    y='DeathRate',
    hue='Year',
    height=5,
    aspect=1.8
)

import matplotlib.pyplot as plt 
plt.title('Death Rates by Age Group for Years 1900, 1950, and 2000')
plt.ylabel('Deaths per 100,000')
plt.xlabel('Age Group')
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3],
#  [Text(0, 0, '01-04 Years'),
#   Text(1, 0, '05-09 Years'),
#   Text(2, 0, '10-14 Years'),
#   Text(3, 0, '15-19 Years')])

# %%
# 10. Create another plot that displays the same data as the plot you created in step 9, but this time, create a subplot for each of the three years. 
#     Display all three subplots in one row.

sns.catplot(
    data=mortality_data.query('Year in [1900, 1950, 2000]'),
    kind='bar',
    x='AgeGroup',
    y='DeathRate',
    col='Year',        
    height=5,
    aspect=0.8       
)

plt.suptitle('Death Rates by Age Group for Years 1900, 1950, and 2000', y=1.05)
# Out:
# Text(0.5, 1.05, 'Death Rates by Age Group for Years 1900, 1950, and 2000')

# %%
# 11. Use a specific method to draw a line plot for just the data in the 15-19 age group, and note the values on the y-axis. 
#     Modify the plot to include an appropriate title, and change the y-axis label to “Deaths per 100,000”.

sns.lineplot(data=mortality_data.query('AgeGroup == "01-04 Years"'),
            x='Year', 
            y='DeathRate',
            legend=False,
            grid=True)

plt.title('Death Rates for Age Group 15-19 Years')
plt.ylabel('Deaths per 100,000')
plt.xlabel('Year')
plt.xticks(rotation=45)
# Out:
# (array([1880., 1900., 1920., 1940., 1960., 1980., 2000., 2020., 2040.]),
#  [Text(1880.0, 0, '1880'),
#   Text(1900.0, 0, '1900'),
#   Text(1920.0, 0, '1920'),
#   Text(1940.0, 0, '1940'),
#   Text(1960.0, 0, '1960'),
#   Text(1980.0, 0, '1980'),
#   Text(2000.0, 0, '2000'),
#   Text(2020.0, 0, '2020'),
#   Text(2040.0, 0, '2040')])

# %%
# 12. Create a line plot that shows the death rates by age group for the years from 1950 to 2000.

sns.lineplot(data=mortality_data.query('Year >= 1950 and Year <= 2000'),
             x='Year', 
             y='DeathRate', 
             hue='AgeGroup')

plt.title('Death Rates by Age Group (1950-2000)')
plt.ylabel('Deaths per 100,000')
plt.xlabel('Year')
plt.xticks(rotation=45)
# Out:
# (array([1940., 1950., 1960., 1970., 1980., 1990., 2000., 2010.]),
#  [Text(1940.0, 0, '1940'),
#   Text(1950.0, 0, '1950'),
#   Text(1960.0, 0, '1960'),
#   Text(1970.0, 0, '1970'),
#   Text(1980.0, 0, '1980'),
#   Text(1990.0, 0, '1990'),
#   Text(2000.0, 0, '2000'),
#   Text(2010.0, 0, '2010')])

# %%
# 13. Create a scatter plot that displays the same data as the line plot you created in step 12. 
#     Set the size and sizes parameters so the plot is easy to read.

plt.figure(figsize=(12, 6))
sns.scatterplot(
    data=mortality_data.query('Year >= 1950 and Year <= 2000'),
    x='Year',
    y='DeathRate',
    hue='AgeGroup',
    size='DeathRate',           
    sizes=(10, 100)         
)


plt.title('Death Rates by Age Group (1950-2000)')
plt.xlabel('Year')
plt.ylabel('Deaths per 100,000')
plt.legend(title='Age Group', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)

# %%
# 14. Create a plot that contains four bar subplots that display the death rates by age group for the years 1900, 1925, 1950, 1975, and 2000. 
#     Display two subplots in each row, and set the height of the plot to an appropriate size. 
#     Add a title to the plot, 
#     and set the label for the y-axis to “Deaths per 100,000”. 
#     Note the position of the title, 
#     and then fix it so it’s displayed above the titles for the subplots. Save the plot to a file named barCharts.png in the same folder as the Notebook.


plt.figure(figsize=(12, 6))
g = sns.catplot(
    data=mortality_data.query('Year in [1900, 1925, 1950, 1975, 2000 ]'), 
    kind='bar', 
    x='Year', 
    y='DeathRate', 
    hue='AgeGroup', 
    legend=False, 
    col='AgeGroup', 
    col_wrap=2, 
    height=4, 
    aspect=1.2
) 

g.fig.suptitle('The death rates by age group for the years 1900, 1925, 1950, 1975, and 2000', y=1.025) 
ageGroups = mortality_data['AgeGroup'].drop_duplicates().tolist() 
for index, ax in enumerate(g.axes.flat): 
    ax.set_title(ageGroups[index]) 
    ax.set_ylabel('Deaths per 100,000') 
#     ax.set_xticks([x for x in range(1910, 1931, 2)]) 
    ax.tick_params('x', labelrotation=45)

plt.tight_layout()
plt.subplots_adjust(top=0.88) 
plt.savefig('barCharts.png')
