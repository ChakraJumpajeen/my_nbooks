# %% [markdown]
# # Chakra Jumpajeen
# ## Phases of Analysis and Visualization

# %% [markdown]
# 1. Get the data
# 2. Clean the data
# 3. Prepare the data
# 4. Analyze the data
# 5. Visualize the data

# %% [markdown]
# # Exercise 1-1: Get started with JupyterLab

# %% [markdown]
# ## Get the data

# %%
import pandas as pd
poll_url = 'http://projects.fivethirtyeight.com/general-model/president_general_polls_2016.csv'
polls = pd.read_csv(poll_url)

# %%
polls
# Out:
#        cycle     branch        type                        matchup  \
# 0       2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 1       2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 2       2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 3       2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 4       2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# ...      ...        ...         ...                            ...
# 12619   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12620   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12621   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12622   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12623   2016  President  polls-only  Clinton vs. Trump vs. Johnson
#
#       forecastdate          state   startdate    enddate  \
# 0          11/8/16           U.S.   11/3/2016  11/6/2016
# 1          11/8/16           U.S.   11/1/2016  11/7/2016
# 2          11/8/16           U.S.   11/2/2016  11/6/2016
# 3          11/8/16           U.S.   11/4/2016  11/7/2016
# 4          11/8/16           U.S.   11/3/2016  11/6/2016
# ...            ...            ...         ...        ...
# 12619      11/8/16  New Hampshire    7/9/2016  7/18/2016
# 12620      11/8/16      Wisconsin  10/21/2016  11/2/2016
# 12621      11/8/16       New York    8/7/2016  8/10/2016
# 12622      11/8/16       Virginia   9/30/2016  10/6/2016
# 12623      11/8/16      Wisconsin    6/9/2016  6/12/2016
#
#                           pollster grade  ...  adjpoll_clinton adjpoll_trump  \
# 0         ABC News/Washington Post    A+  ...         45.20163      41.72430
# 1          Google Consumer Surveys     B  ...         43.34557      41.21439
# 2                            Ipsos    A-  ...         42.02638      38.81620
# 3                           YouGov     B  ...         45.65676      40.92004
# 4                 Gravis Marketing    B-  ...         46.84089      42.33184
# ...                            ...   ...  ...              ...           ...
# 12619  University of New Hampshire    B+  ...         40.24983      43.04717
# 12620                        Ipsos    A-  ...         46.54218      38.96884
# 12621                Siena College     A  ...         53.83622      32.47939
# 12622                        Ipsos    A-  ...         49.57558      39.96954
# 12623         Marquette University     A  ...         46.40999      39.19839
#
#        adjpoll_johnson  adjpoll_mcmullin  multiversions  \
# 0             4.626221               NaN            NaN
# 1             5.175792               NaN            NaN
# 2             6.844734               NaN            NaN
# 3             6.069454               NaN            NaN
# 4             3.726098               NaN            NaN
# ...                ...               ...            ...
# 12619         6.924110               NaN            NaN
# 12620              NaN               NaN            NaN
# 12621         3.881193               NaN            NaN
# 12622              NaN               NaN            NaN
# 12623              NaN               NaN            NaN
#
#                                                      url  poll_id  \
# 0      https://www.washingtonpost.com/news/the-fix/wp...    48630
# 1      https://datastudio.google.com/u/0/#/org//repor...    48847
# 2      http://projects.fivethirtyeight.com/polls/2016...    48922
# 3      https://d25d2506sfb94s.cloudfront.net/cumulus_...    48687
# 4      http://www.gravispolls.com/2016/11/final-natio...    48848
# ...                                                  ...      ...
# 12619  https://cola.unh.edu/sites/cola.unh.edu/files/...    44650
# 12620          http://www.reuters.com/statesofthenation/    48259
# 12621  https://www.siena.edu/assets/files/news/SNY081...    44852
# 12622          http://www.reuters.com/statesofthenation/    46675
# 12623  https://law.marquette.edu/poll/2016/06/15/new-...    44341
#
#        question_id  createddate             timestamp
# 0            76192      11/7/16  09:35:33  8 Nov 2016
# 1            76443      11/7/16  09:35:33  8 Nov 2016
# 2            76636      11/8/16  09:35:33  8 Nov 2016
# 3            76262      11/7/16  09:35:33  8 Nov 2016
# 4            76444      11/7/16  09:35:33  8 Nov 2016
# ...            ...          ...                   ...
# 12619        68189      7/21/16  09:14:14  8 Nov 2016
# 12620        75560      11/3/16  09:14:14  8 Nov 2016
# 12621        68743      8/15/16  09:14:14  8 Nov 2016
# 12622        72969     10/10/16  09:14:14  8 Nov 2016
# 12623        66966      6/15/16  09:14:14  8 Nov 2016
#
# [12624 rows x 27 columns]

# %%
polls.sort_values('state', inplace=True)
polls.head()
# Out:
#        cycle     branch        type                        matchup  \
# 12475   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 6497    2016  President    now-cast  Clinton vs. Trump vs. Johnson
# 4610    2016  President    now-cast  Clinton vs. Trump vs. Johnson
# 8930    2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 5554    2016  President    now-cast  Clinton vs. Trump vs. Johnson
#
#       forecastdate    state   startdate     enddate                 pollster  \
# 12475      11/8/16  Alabama  10/21/2016   11/2/2016                    Ipsos
# 6497       11/8/16  Alabama    9/2/2016   9/22/2016                    Ipsos
# 4610       11/8/16  Alabama   11/1/2016   11/7/2016  Google Consumer Surveys
# 8930       11/8/16  Alabama   10/4/2016   11/6/2016                   YouGov
# 5554       11/8/16  Alabama  10/20/2016  10/24/2016  Google Consumer Surveys
#
#       grade  ...  adjpoll_clinton adjpoll_trump  adjpoll_johnson  \
# 12475    A-  ...         40.48323      53.28125              NaN
# 6497     A-  ...         39.23778      53.55209              NaN
# 4610      B  ...         25.54403      66.17603         3.755080
# 8930      B  ...         32.43530      54.65168         3.561469
# 5554      B  ...         27.67931      64.28975         1.485673
#
#        adjpoll_mcmullin  multiversions  \
# 12475               NaN            NaN
# 6497                NaN            NaN
# 4610                NaN            NaN
# 8930                NaN            NaN
# 5554                NaN            NaN
#
#                                                      url  poll_id  \
# 12475          http://www.reuters.com/statesofthenation/    48213
# 6497           http://www.reuters.com/statesofthenation/    46056
# 4610   https://datastudio.google.com/u/0/#/org//repor...    48794
# 8930   http://projects.fivethirtyeight.com/polls/2016...    48719
# 5554   https://datastudio.google.com/u/0/#/org//repor...    47357
#
#        question_id  createddate             timestamp
# 12475        75514      11/3/16  09:14:14  8 Nov 2016
# 6497         72048      9/26/16  09:24:53  8 Nov 2016
# 4610         76383      11/7/16  09:24:53  8 Nov 2016
# 8930         76300      11/7/16  09:14:14  8 Nov 2016
# 5554         74394     10/27/16  09:24:53  8 Nov 2016
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Use Tab completion and tooltips

# %%
polls.sort_values('state', ascending=False)
polls.head()
# Out:
#        cycle     branch        type                        matchup  \
# 12475   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 6497    2016  President    now-cast  Clinton vs. Trump vs. Johnson
# 4610    2016  President    now-cast  Clinton vs. Trump vs. Johnson
# 8930    2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 5554    2016  President    now-cast  Clinton vs. Trump vs. Johnson
#
#       forecastdate    state   startdate     enddate                 pollster  \
# 12475      11/8/16  Alabama  10/21/2016   11/2/2016                    Ipsos
# 6497       11/8/16  Alabama    9/2/2016   9/22/2016                    Ipsos
# 4610       11/8/16  Alabama   11/1/2016   11/7/2016  Google Consumer Surveys
# 8930       11/8/16  Alabama   10/4/2016   11/6/2016                   YouGov
# 5554       11/8/16  Alabama  10/20/2016  10/24/2016  Google Consumer Surveys
#
#       grade  ...  adjpoll_clinton adjpoll_trump  adjpoll_johnson  \
# 12475    A-  ...         40.48323      53.28125              NaN
# 6497     A-  ...         39.23778      53.55209              NaN
# 4610      B  ...         25.54403      66.17603         3.755080
# 8930      B  ...         32.43530      54.65168         3.561469
# 5554      B  ...         27.67931      64.28975         1.485673
#
#        adjpoll_mcmullin  multiversions  \
# 12475               NaN            NaN
# 6497                NaN            NaN
# 4610                NaN            NaN
# 8930                NaN            NaN
# 5554                NaN            NaN
#
#                                                      url  poll_id  \
# 12475          http://www.reuters.com/statesofthenation/    48213
# 6497           http://www.reuters.com/statesofthenation/    46056
# 4610   https://datastudio.google.com/u/0/#/org//repor...    48794
# 8930   http://projects.fivethirtyeight.com/polls/2016...    48719
# 5554   https://datastudio.google.com/u/0/#/org//repor...    47357
#
#        question_id  createddate             timestamp
# 12475        75514      11/3/16  09:14:14  8 Nov 2016
# 6497         72048      9/26/16  09:24:53  8 Nov 2016
# 4610         76383      11/7/16  09:24:53  8 Nov 2016
# 8930         76300      11/7/16  09:14:14  8 Nov 2016
# 5554         74394     10/27/16  09:24:53  8 Nov 2016
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Clean the data

# %% [markdown]
# ### Keep only the rows with "now-cast" in the type column

# %%
polls = polls.query('type=="now-cast"')
polls.head()
# Out:
#       cycle     branch      type                        matchup forecastdate  \
# 6497   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 4610   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 5554   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 7530   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 5504   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
#
#         state   startdate     enddate                 pollster grade  ...  \
# 6497  Alabama    9/2/2016   9/22/2016                    Ipsos    A-  ...
# 4610  Alabama   11/1/2016   11/7/2016  Google Consumer Surveys     B  ...
# 5554  Alabama  10/20/2016  10/24/2016  Google Consumer Surveys     B  ...
# 7530  Alabama   8/17/2016   8/23/2016  Google Consumer Surveys     B  ...
# 5504  Alabama   7/19/2016   7/19/2016        Strategy Research   NaN  ...
#
#       adjpoll_clinton adjpoll_trump  adjpoll_johnson  adjpoll_mcmullin  \
# 6497         39.23778      53.55209              NaN               NaN
# 4610         25.54403      66.17603         3.755080               NaN
# 5554         27.67931      64.28975         1.485673               NaN
# 7530         25.27439      65.91888         1.217370               NaN
# 5504         34.09074      57.64280              NaN               NaN
#
#       multiversions                                                url  \
# 6497            NaN          http://www.reuters.com/statesofthenation/
# 4610            NaN  https://datastudio.google.com/u/0/#/org//repor...
# 5554            NaN  https://datastudio.google.com/u/0/#/org//repor...
# 7530            NaN  https://drive.google.com/drive/u/0/folders/0B2...
# 5504            NaN  http://wkrg.com/2016/07/21/trump-wins-alabama-...
#
#       poll_id  question_id  createddate             timestamp
# 6497    46056        72048      9/26/16  09:24:53  8 Nov 2016
# 4610    48794        76383      11/7/16  09:24:53  8 Nov 2016
# 5554    47357        74394     10/27/16  09:24:53  8 Nov 2016
# 7530    45542        70927       9/9/16  09:24:53  8 Nov 2016
# 5504    44747        68431       8/2/16  09:24:53  8 Nov 2016
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Rename voting columns

# %%
polls.rename(columns={'rawpoll_clinton':'Clinton_pct',
                      'rawpoll_trump':'Trump_pct'},inplace=True)
polls.head()
# Out:
# /var/folders/dd/gbd6vl0j6m9g65j67lnzff_c0000gn/T/ipykernel_6596/4063675258.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   polls.rename(columns={'rawpoll_clinton':'Clinton_pct',
#       cycle     branch      type                        matchup forecastdate  \
# 6497   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 4610   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 5554   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 7530   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 5504   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
#
#         state   startdate     enddate                 pollster grade  ...  \
# 6497  Alabama    9/2/2016   9/22/2016                    Ipsos    A-  ...
# 4610  Alabama   11/1/2016   11/7/2016  Google Consumer Surveys     B  ...
# 5554  Alabama  10/20/2016  10/24/2016  Google Consumer Surveys     B  ...
# 7530  Alabama   8/17/2016   8/23/2016  Google Consumer Surveys     B  ...
# 5504  Alabama   7/19/2016   7/19/2016        Strategy Research   NaN  ...
#
#       adjpoll_clinton adjpoll_trump  adjpoll_johnson  adjpoll_mcmullin  \
# 6497         39.23778      53.55209              NaN               NaN
# 4610         25.54403      66.17603         3.755080               NaN
# 5554         27.67931      64.28975         1.485673               NaN
# 7530         25.27439      65.91888         1.217370               NaN
# 5504         34.09074      57.64280              NaN               NaN
#
#       multiversions                                                url  \
# 6497            NaN          http://www.reuters.com/statesofthenation/
# 4610            NaN  https://datastudio.google.com/u/0/#/org//repor...
# 5554            NaN  https://datastudio.google.com/u/0/#/org//repor...
# 7530            NaN  https://drive.google.com/drive/u/0/folders/0B2...
# 5504            NaN  http://wkrg.com/2016/07/21/trump-wins-alabama-...
#
#       poll_id  question_id  createddate             timestamp
# 6497    46056        72048      9/26/16  09:24:53  8 Nov 2016
# 4610    48794        76383      11/7/16  09:24:53  8 Nov 2016
# 5554    47357        74394     10/27/16  09:24:53  8 Nov 2016
# 7530    45542        70927       9/9/16  09:24:53  8 Nov 2016
# 5504    44747        68431       8/2/16  09:24:53  8 Nov 2016
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Convert date columns to datetime objects

# %%
date_cols = ["startdate","enddate"]
polls[date_cols] = polls[date_cols].apply(pd.to_datetime)
polls.head()
# Out:
# /var/folders/dd/gbd6vl0j6m9g65j67lnzff_c0000gn/T/ipykernel_6596/732497925.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   polls[date_cols] = polls[date_cols].apply(pd.to_datetime)
#       cycle     branch      type                        matchup forecastdate  \
# 6497   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 4610   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 5554   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 7530   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 5504   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
#
#         state  startdate    enddate                 pollster grade  ...  \
# 6497  Alabama 2016-09-02 2016-09-22                    Ipsos    A-  ...
# 4610  Alabama 2016-11-01 2016-11-07  Google Consumer Surveys     B  ...
# 5554  Alabama 2016-10-20 2016-10-24  Google Consumer Surveys     B  ...
# 7530  Alabama 2016-08-17 2016-08-23  Google Consumer Surveys     B  ...
# 5504  Alabama 2016-07-19 2016-07-19        Strategy Research   NaN  ...
#
#       adjpoll_clinton adjpoll_trump  adjpoll_johnson  adjpoll_mcmullin  \
# 6497         39.23778      53.55209              NaN               NaN
# 4610         25.54403      66.17603         3.755080               NaN
# 5554         27.67931      64.28975         1.485673               NaN
# 7530         25.27439      65.91888         1.217370               NaN
# 5504         34.09074      57.64280              NaN               NaN
#
#       multiversions                                                url  \
# 6497            NaN          http://www.reuters.com/statesofthenation/
# 4610            NaN  https://datastudio.google.com/u/0/#/org//repor...
# 5554            NaN  https://datastudio.google.com/u/0/#/org//repor...
# 7530            NaN  https://drive.google.com/drive/u/0/folders/0B2...
# 5504            NaN  http://wkrg.com/2016/07/21/trump-wins-alabama-...
#
#       poll_id  question_id  createddate             timestamp
# 6497    46056        72048      9/26/16  09:24:53  8 Nov 2016
# 4610    48794        76383      11/7/16  09:24:53  8 Nov 2016
# 5554    47357        74394     10/27/16  09:24:53  8 Nov 2016
# 7530    45542        70927       9/9/16  09:24:53  8 Nov 2016
# 5504    44747        68431       8/2/16  09:24:53  8 Nov 2016
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Try two plots

# %%
polls.plot.line(x='enddate',y=['Clinton_pct','Trump_pct'])
# Out:
# <Axes: xlabel='enddate'>

# %%
# %%time
polls.query('state == "U.S."') \
    .plot(x='enddate',y=['Clinton_pct','Trump_pct'])
# Out:
# CPU times: user 25.3 ms, sys: 17.9 ms, total: 43.3 ms
# Wall time: 42.5 ms
# <Axes: xlabel='enddate'>

# %%
# %whos
# Out:
# Variable               Type             Data/Info
# -------------------------------------------------
# NamespaceMagics        MetaHasTraits    <class 'IPython.core.magi<...>mespace.NamespaceMagics'>
# dataframe_columns      function         <function dataframe_columns at 0x157fdbc40>
# dataframe_hash         function         <function dataframe_hash at 0x157fdab60>
# date_cols              list             n=2
# dtypes_str             function         <function dtypes_str at 0x157fdbba0>
# get_dataframes         function         <function get_dataframes at 0x156e34ae0>
# get_ipython            function         <function get_ipython at 0x1045b6520>
# getpass                module           <module 'getpass' from '/<...>b/python3.12/getpass.py'>
# hashlib                module           <module 'hashlib' from '/<...>b/python3.12/hashlib.py'>
# import_pandas_safely   function         <function import_pandas_safely at 0x16814c900>
# is_data_frame          function         <function is_data_frame at 0x16814c9a0>
# json                   module           <module 'json' from '/opt<...>on3.12/json/__init__.py'>
# pd                     module           <module 'pandas' from '/o<...>ages/pandas/__init__.py'>
# poll_url               str              http://projects.fivethirt<...>nt_general_polls_2016.csv
# polls                  DataFrame              cycle     branch   <...>n[4208 rows x 27 columns]
# sys                    module           <module 'sys' (built-in)>

# %%
type(polls)
# Out:
# pandas.core.frame.DataFrame
